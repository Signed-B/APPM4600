# %%
from bisection_example import bisection
import numpy as np

# %%
f = lambda x: np.sin(x) - 2*x + 1

bisection(f, 0, np.pi/2, tol=1e-8, Nmax=1000)
# Out:
# [0.8878622096305406, 0, 27]

# %%
bisection(lambda x: (x-5)**9, 4.82, 5.2, 1e-4, 100)
# Out:
# [4.9999804687500005, 0, 11]

# %%
f = lambda x: x**9 - 45 *x**8 + 900*x**7 - 10500*x**6 + 78750*x**5 - 393750*x**4 \
            + 1312500*x**3 - 2812500*x**2 + 3515625*x - 1953125
bisection(f, 4.82, 5.2, 1e-4, 100)
# Out:
# [5.12875, 0, 3]

# %%
import matplotlib.pyplot as plt
x = np.linspace(4.8, 5.2, 1000)
plt.plot(x, f(x))
plt.grid()

# %%
bisection(lambda x: x**3 + x - 4, 1, 4, 1e-3, 100)
# Out:
# [1.378662109375, 0, 11]

# %%
from fixedpt import fixedpt

# %%
fixedpt(lambda x: 12/(1+x),1,1e-4,100)
# Out:
# [3.0000375447859753, 0]

# %% [markdown]
# ## Q5

# %%
f = lambda x: x-4*np.sin(2*x) - 3
x = np.linspace(-2, 8, 1000)
plt.plot(x, f(x))
plt.grid()

# %%
fixedpt(lambda x: -np.sin(2*x) + 5*x/4 - 3/4, -1, 1e-10, 100)
# Out:
# [-11691525728.540548, 1]
